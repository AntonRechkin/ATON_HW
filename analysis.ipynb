# %% [markdown]
# # Анализ корпоративных связей\n\nОбработка файла corporate_links_raw.xlsx [file:1]

# %%
import sys\nsys.path.append("..")\nfrom src.data_cleaning import *\n\ndf = load_data("../data/raw/corporate_links_raw.xlsx")\ndf_clean = clean_data(df)\ndf_clean.head(10)

# %%
results, _ = analyze_data(df_clean)\nresults
